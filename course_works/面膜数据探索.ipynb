# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_data = pd.read_csv("original_data.csv",encoding="ANSI")

# %%
original_data.head()
# Out:
#        名称     价格   月销量    评价数 店铺所在地  适合肤质  产地  补水保湿  美白提亮  控油祛痘  清洁毛孔  提拉紧致
# 0  ANGLEE  254.0    40   3133    湖南  任何肤质  中国     1     1     0     0     0
# 1  ANGLEE  350.0    62    876    浙江  任何肤质  中国     1     1     0     0     0
# 2  ANGLEE  284.9    12     16    浙江  任何肤质  中国     1     0     1     1     0
# 3      BF  289.0    32    175    英国  任何肤质  中国     1     0     0     0     0
# 4     BSR  379.9  1407  13870    安徽  任何肤质  中国     1     0     0     0     0

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
correlations = original_data.corr() 
correction=abs(correlations)# 取绝对值，只看相关程度 ，不关心正相关还是负相关
# plot correlation matrix 
ax = sns.heatmap(correction,cmap=plt.cm.Greys, linewidths=0.05,vmax=1, vmin=0 ,annot=True,annot_kws={'size':6,'weight':'bold'})

# %%
df=pd.DataFrame(original_data)

# %%
df.head()
# Out:
#        名称     价格   月销量    评价数 店铺所在地  适合肤质  产地  补水保湿  美白提亮  控油祛痘  清洁毛孔  提拉紧致
# 0  ANGLEE  254.0    40   3133    湖南  任何肤质  中国     1     1     0     0     0
# 1  ANGLEE  350.0    62    876    浙江  任何肤质  中国     1     1     0     0     0
# 2  ANGLEE  284.9    12     16    浙江  任何肤质  中国     1     0     1     1     0
# 3      BF  289.0    32    175    英国  任何肤质  中国     1     0     0     0     0
# 4     BSR  379.9  1407  13870    安徽  任何肤质  中国     1     0     0     0     0

# %%
#价格分布直方图
plt.figure(figsize = (8,5))
sns.set_palette("hls") 
sns.distplot(df.iloc[:,1],color="grey",bins=80,kde=True,hist=True,rug=True)
# Out:
# B:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#0~500之间的
plt.figure(figsize = (8,5))
sns.set_palette("hls") 
sns.distplot(df.iloc[:,1],color="grey",bins=150,kde=True,hist=True,rug=True)
plt.xlim(0,500)
from matplotlib.ticker import MultipleLocator
xmajorLocator= MultipleLocator(25)
ax = plt.subplot(111)
ax.xaxis.set_major_locator(xmajorLocator)
# Out:
# B:\anaconda\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
df.head()
# Out:
#        名称     价格   月销量    评价数 店铺所在地  适合肤质  产地  补水保湿  美白提亮  控油祛痘  清洁毛孔  提拉紧致
# 0  ANGLEE  254.0    40   3133    湖南  任何肤质  中国     1     1     0     0     0
# 1  ANGLEE  350.0    62    876    浙江  任何肤质  中国     1     1     0     0     0
# 2  ANGLEE  284.9    12     16    浙江  任何肤质  中国     1     0     1     1     0
# 3      BF  289.0    32    175    英国  任何肤质  中国     1     0     0     0     0
# 4     BSR  379.9  1407  13870    安徽  任何肤质  中国     1     0     0     0     0

# %%
#不同适合肤质的价格箱线图
sns.catplot(x='适合肤质',y='价格',kind='box',
           data=df,aspect = 2,palette="Greys") 
sns.catplot(x='适合肤质',y='价格',kind='box',
           data=df,aspect = 2,showfliers=False,palette="Greys")

# %%
df_allface = df[df['适合肤质']=='任何肤质']

# %%
sns.catplot(x='产地',y='价格',kind='box',
           data=df_allface,aspect = 1,showfliers=True,palette="Greys") 
sns.catplot(x='产地',y='价格',kind='box',
           data=df_allface,aspect = 1,showfliers=False,palette="Greys")

# %%
df.head()
# Out:
#        名称     价格   月销量    评价数 店铺所在地  适合肤质  产地  补水保湿  美白提亮  控油祛痘  清洁毛孔  提拉紧致
# 0  ANGLEE  254.0    40   3133    湖南  任何肤质  中国     1     1     0     0     0
# 1  ANGLEE  350.0    62    876    浙江  任何肤质  中国     1     1     0     0     0
# 2  ANGLEE  284.9    12     16    浙江  任何肤质  中国     1     0     1     1     0
# 3      BF  289.0    32    175    英国  任何肤质  中国     1     0     0     0     0
# 4     BSR  379.9  1407  13870    安徽  任何肤质  中国     1     0     0     0     0

# %%
list_count=[]
list_name=[]
for i in np.arange(7,12):
    list_count.append(df[df.iloc[:,i]==1].shape[0])
    list_name.append( df.columns[i])

# %%
df_use=[list_name,list_count]

# %%
df_use=pd.DataFrame(df_use)

# %%
df2 = pd.DataFrame(df_use.values.T)

# %%
df2
# Out:
#       0    1
# 0  补水保湿  769
# 1  美白提亮  505
# 2  控油祛痘  301
# 3  清洁毛孔  368
# 4  提拉紧致  185

# %%
df3=df2.sort_values(1, ascending=False)

# %%
#_01各大功能占比
plt.figure(figsize = (6,5))
plt.xticks(np.arange(len(df3[1])),df3[0])
plt.bar(np.arange(len(df3[1])),df3[1],color='grey',alpha=0.7)
plt.xlabel('功能',color='black')
plt.ylabel('数量',color='black')
for a,b in zip(np.arange(len(df3[1])),df3[1]):
    plt.text(a, b+10, '%.0f' % b, ha='center', va= 'bottom',fontsize=11)
plt.show()

# %%
#_02 一款能有几个功能 Tab
#_03 两/三个功能组合 -价格 Tab
#_04 单个功能和价格 Tab

# %%
#微观_爆款分析
df_liang=df.sort_values("月销量", ascending=False)

# %%
df_liang
# Out:
#          名称     价格    月销量     评价数 店铺所在地     适合肤质  产地  补水保湿  美白提亮  控油祛痘  清洁毛孔  \
# 395  精装金美芙坊  159.0  49694  405515    广东     任何肤质  中国     1     0     0     0
# 82      安马仕  239.0  39214  282961    广东     任何肤质  中国     1     1     1     1
# 14      CML  117.0  33896  187356    湖北     任何肤质  中国     1     0     1     1
# 517     欧诗漫  198.0  33537   26883    浙江     任何肤质  中国     1     1     0     0
# 252    法兰琳卡  173.5  25903   13725    上海     任何肤质  日本     1     0     0     0
# ..      ...    ...    ...     ...   ...      ...  ..   ...   ...   ...   ...
# 211      瓷肌  280.0      2      52    广东     任何肤质  中国     1     0     0     0
# 691    相宜本草  315.0      1     104    上海     任何肤质  中国     1     1     0     0
# 538     珀莱雅  128.0      1       1    上海     任何肤质  美国     1     0     1     1
# 751     植美村  129.0      0       4    广东  中性及干性肤质  中国     1     0     0     0
# 49   SIROSE  412.0      0       5    广东     任何肤质  中国     1     1     1     1
#
#      提拉紧致
# 395     0
# 82      0
# ...

# %%
total_amount=sum(df["月销量"])

# %%
total_amount
# Out:
# 1018006

# %%
df_liang.iloc[0,2]
# Out:
# 49694

# %%
 #累计销量
cal_amount=0
list_amount=[]
for i in np.arange(794):
    cal_amount+=df_liang.iloc[i,2]
    list_amount.append(cal_amount)
plt.plot(np.arange(794),list_amount,color='grey')
plt.xlabel('面膜种类数')
plt.ylabel('销售数量')
plt.annotate("60%的销售量被前55种面膜占有", (55,615322),xytext=(155,615322),arrowprops=dict(arrowstyle='->')) 
plt.annotate("80%的销售量被前132种面膜占有", (132,815164),xytext=(232,815164),arrowprops=dict(arrowstyle='->'))
# Out:
# Text(232, 815164, '80%的销售量被前132种面膜占有')

# %%
list_amount[132]
# Out:
# 815164

# %%
list_per=[a/1018006 for a in list_amount]

# %%
df_per=[np.arange(794),list_per]

# %%
df_per=pd.DataFrame(df_per.values.T)

# %%
df_per.head(60)#60%的销售量被前55种面膜占有
# Out:
#        0         1
# 0    0.0  0.048815
# 1    1.0  0.087335
# 2    2.0  0.120632
# 3    3.0  0.153576
# 4    4.0  0.179021
# 5    5.0  0.204358
# 6    6.0  0.229551
# 7    7.0  0.254499
# 8    8.0  0.278198
# 9    9.0  0.300136
# 10  10.0  0.319653
# 11  11.0  0.338212
# 12  12.0  0.353802
# 13  13.0  0.368127
# 14  14.0  0.380070
# 15  15.0  0.391284
# 16  16.0  0.401308
# 17  17.0  0.409670
# 18  18.0  0.417956
# 19  19.0  0.425840
# 20  20.0  0.433597
# 21  21.0  0.440774
# 22  22.0  0.447870
# 23  23.0  0.454698
# 24  24.0  0.461024
# 25  25.0  0.467023
# 26  26.0  0.472660
# 27  27.0  0.478192
# 28  28.0  0.483617
# 29  29.0  0.488939
# 30  30.0  0.494160
# 31  31.0  0.499200
# 32  32.0  0.504211
# 33  33.0  0.509076
# 34  34.0  0.513915
# 35  35.0  0.518745
# 36  36.0  0.523537
# 37  37.0  0.528237
# 38  38.0  0.532910
# 39  39.0  0.537550
# 40  40.0  0.542057
# 41  41.0  0.546548
# 42  42.0  0.551020
# 43  43.0  0.555441
# 44  44.0  0.559786
# 45  45.0  0.564128
# ...

# %%
print(df_per.iloc[132])#80%的销售量被前132种面膜占有
# Out:
# 0    132.000000
# 1      0.800746
# Name: 132, dtype: float64

# %%
df.head()
# Out:
#        名称     价格   月销量    评价数 店铺所在地  适合肤质  产地  补水保湿  美白提亮  控油祛痘  清洁毛孔  提拉紧致
# 0  ANGLEE  254.0    40   3133    湖南  任何肤质  中国     1     1     0     0     0
# 1  ANGLEE  350.0    62    876    浙江  任何肤质  中国     1     1     0     0     0
# 2  ANGLEE  284.9    12     16    浙江  任何肤质  中国     1     0     1     1     0
# 3      BF  289.0    32    175    英国  任何肤质  中国     1     0     0     0     0
# 4     BSR  379.9  1407  13870    安徽  任何肤质  中国     1     0     0     0     0

# %%
#多因素方差分析，选取独立、正态分布的定类变量
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

formula = '月销量~ 名称+店铺所在地+适合肤质+产地'#但是名称取值太多了吧
anova_results = anova_lm(ols(formula,df).fit())
print(anova_results)
# Out:
#              df        sum_sq       mean_sq         F        PR(>F)
# 名称        209.0  5.402623e+09  2.584987e+07  2.180435  4.500286e-13
# 店铺所在地      25.0  1.264529e+08  5.058117e+06  0.426652  9.939442e-01
# 适合肤质        7.0  2.482889e+07  3.546985e+06  0.299188  9.541121e-01
# 产地          5.0  8.258319e+07  1.651664e+07  1.393177  2.250498e-01
# Residual  555.0  6.579731e+09  1.185537e+07       NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
print(pairwise_tukeyhsd(df['月销量'], df['名称']))
# Out:
#                   Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ...
#         group1                group2          meandiff     lower       upper    reject
# --------------------------------------------------------------------------------------
#         ANGLEE                  BF              -6.0    -18308.2376  18296.2376 False
#         ANGLEE                 BSR             318.4    -11256.9514  11893.7514 False
#         ANGLEE                 CML            8691.75    -3414.0423  20797.5423 False
#         ANGLEE                CO.E韩伊           8475.0    -9827.2376  26777.2376 False
#         ANGLEE                 DHC              90.0    -18212.2376  18392.2376 False
#         ANGLEE          Dreamtimes M2梦幻三部曲     177.0    -18125.2376  18479.2376 False
#         ANGLEE               EXCEL萱姿           2395.5   -12073.6893  16864.6893 False
#         ANGLEE                Eunice           425.0    -17877.2376  18727.2376 False
# ...

# %%
#线性回归
import os
from sklearn.linear_model import LassoLars
from sklearn.linear_model import Lasso
#from keras.models import Sequential 
#from keras.layers.core import Dense, Activation

# %%
# !pip install category_encoders
# Out:
# ...
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000295A5742128>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/a0/52/c54191ad3782de633ea3d6ee3bb2837bda0cf3bc97644bb6375cf14150a0/category_encoders-2.1.0-py2.py3-none-any.whl

# %%
import category_encoders as ce

# %%
encoder = ce.BinaryEncoder(cols=['适合肤质','店铺所在地','产地']).fit(df)

# %%
numeric_dataset = encoder.transform(df)

# %%
numeric_dataset.head(50)
# Out:
#                     名称      价格    月销量     评价数  店铺所在地_0  店铺所在地_1  店铺所在地_2  \
# 0               ANGLEE  254.00     40    3133        0        0        0
# 1               ANGLEE  350.00     62     876        0        0        0
# 2               ANGLEE  284.90     12      16        0        0        0
# 3                   BF  289.00     32     175        0        0        0
# 4                  BSR  379.90   1407   13870        0        0        0
# 5                  BSR  345.00    318     391        0        0        0
# 6                  BSR  299.00      8      45        0        0        0
# 7                  BSR  266.50     20     369        0        0        0
# 8                  BSR  209.00     29      80        0        0        0
# 9              calibio  454.00   4120   21261        0        0        0
# 10               chen川  319.00     20      28        0        0        0
# 11                 CML  413.50    791    1421        0        0        0
# ...

# %%
df_x=pd.concat([numeric_dataset.iloc[:,1:2],numeric_dataset.iloc[:,3:4],numeric_dataset.iloc[:,3:4]],axis=1)
df_y=numeric_dataset.iloc[:,2]

# %%
df_x
# Out:
#         价格    评价数  店铺所在地_0  店铺所在地_1  店铺所在地_2  店铺所在地_3  店铺所在地_4  店铺所在地_5  \
# 0    254.0   3133        0        0        0        0        0        1
# 1    350.0    876        0        0        0        0        1        0
# 2    284.9     16        0        0        0        0        1        0
# 3    289.0    175        0        0        0        0        1        1
# 4    379.9  13870        0        0        0        1        0        0
# ..     ...    ...      ...      ...      ...      ...      ...      ...
# 789  122.0   1715        0        0        1        0        0        0
# 790  112.5   1887        0        0        1        0        0        0
# 791   29.0    297        0        0        1        0        0        0
# 792  173.0   2389        0        0        0        0        1        0
# 793  119.0    106        0        0        0        0        1        0
#
#      适合肤质_0  适合肤质_1  ...  适合肤质_3  产地_0  产地_1  产地_2  产地_3  补水保湿  美白提亮  控油祛痘  \
# ...

# %%
model = LassoLars(alpha=1)  # LASSO回归的特点是在拟合广义线性模型的同时进行变量筛选和复杂度调整，剔除存在共线性的变量
model.fit(df_x,df_y)
#pd.DataFrame(model.coef_,columns=['x%d' %i for i in np.arange(13)+1])
model_coef=pd.DataFrame(pd.DataFrame(model.coef_).T)
model_coef.columns=['x%d' %i for i in np.arange(21)+1]
pd.set_option('display.max_columns', None)
model_coef
# Out:
#          x1        x2   x3   x4   x5         x6         x7   x8   x9  x10  \
# 0 -0.659185  0.106663  0.0  0.0  0.0 -48.377403  99.503182  0.0  0.0  0.0
#
#           x11        x12  x13          x14        x15          x16  x17  x18  \
# 0  283.983842  60.172576  0.0 -3224.626307  46.555074 -3841.520696  0.0  0.0
#
#         x19         x20       x21
# 0  5.154548 -212.968462  4.299425

# %%
model
# Out:
# LassoLars(alpha=1, copy_X=True, eps=2.220446049250313e-16, fit_intercept=True,
#      fit_path=True, max_iter=500, normalize=True, positive=False,
#      precompute='auto', verbose=False)

# %%
df_a=pd.DataFrame(df_x.columns)

# %%
df_a
# Out:
#           0
# 0        价格
# 1       评价数
# 2   店铺所在地_0
# 3   店铺所在地_1
# 4   店铺所在地_2
# 5   店铺所在地_3
# 6   店铺所在地_4
# 7   店铺所在地_5
# 8    适合肤质_0
# 9    适合肤质_1
# 10   适合肤质_2
# 11   适合肤质_3
# 12     产地_0
# 13     产地_1
# 14     产地_2
# 15     产地_3
# 16     补水保湿
# 17     美白提亮
# 18     控油祛痘
# 19     清洁毛孔
# 20     提拉紧致

# %%
model_coef.T
# Out:
#                0
# x1     -0.659185
# x2      0.106663
# x3      0.000000
# x4      0.000000
# x5      0.000000
# x6    -48.377403
# x7     99.503182
# x8      0.000000
# x9      0.000000
# x10     0.000000
# x11   283.983842
# x12    60.172576
# x13     0.000000
# x14 -3224.626307
# x15    46.555074
# x16 -3841.520696
# x17     0.000000
# x18     0.000000
# x19     5.154548
# x20  -212.968462
# x21     4.299425

# %%
df_b = pd.concat([df_a,model_coef.T],axis=1)

# %%
df_b
# Out:
#             0
# 0          价格
# 1         评价数
# 2     店铺所在地_0
# 3     店铺所在地_1
# 4     店铺所在地_2
# 5     店铺所在地_3
# 6     店铺所在地_4
# 7     店铺所在地_5
# 8      适合肤质_0
# 9      适合肤质_1
# 10     适合肤质_2
# 11     适合肤质_3
# 12       产地_0
# 13       产地_1
# 14       产地_2
# 15       产地_3
# 16       补水保湿
# 17       美白提亮
# 18       控油祛痘
# 19       清洁毛孔
# 20       提拉紧致
# x1  -0.659185
# x2   0.106663
# x3          0
# x4          0
# x5          0
# x6   -48.3774
# x7    99.5032
# x8          0
# x9          0
# x10         0
# x11   283.984
# x12   60.1726
# x13         0
# x14  -3224.63
# x15   46.5551
# x16  -3841.52
# x17         0
# x18         0
# x19   5.15455
# x20  -212.968
# x21   4.29943

# %%
print('系数矩阵:\n',model.coef_)
# Out:
# 系数矩阵:
#  [-6.59184729e-01  1.06663313e-01  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -4.83774030e+01  9.95031819e+01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  2.83983842e+02  6.01725755e+01
#   0.00000000e+00 -3.22462631e+03  4.65550744e+01 -3.84152070e+03
#   0.00000000e+00  0.00000000e+00  5.15454777e+00 -2.12968462e+02
#   4.29942541e+00]

# %%
print('线性回归模型:\n',model)
# Out:
# 线性回归模型:
#  LassoLars(alpha=1, copy_X=True, eps=2.220446049250313e-16, fit_intercept=True,
#      fit_path=True, max_iter=500, normalize=True, positive=False,
#      precompute='auto', verbose=False)

# %%
df_x
# Out:
#         价格    评价数  店铺所在地_0  店铺所在地_1  店铺所在地_2  店铺所在地_3  店铺所在地_4  店铺所在地_5  \
# 0    254.0   3133        0        0        0        0        0        1
# 1    350.0    876        0        0        0        0        1        0
# 2    284.9     16        0        0        0        0        1        0
# 3    289.0    175        0        0        0        0        1        1
# 4    379.9  13870        0        0        0        1        0        0
# ..     ...    ...      ...      ...      ...      ...      ...      ...
# 789  122.0   1715        0        0        1        0        0        0
# 790  112.5   1887        0        0        1        0        0        0
# 791   29.0    297        0        0        1        0        0        0
# 792  173.0   2389        0        0        0        0        1        0
# 793  119.0    106        0        0        0        0        1        0
#
#      适合肤质_0  适合肤质_1  适合肤质_2  适合肤质_3  产地_0  产地_1  产地_2  产地_3  补水保湿  美白提亮  控油祛痘  \
# ...

# %%
df.columns
# Out:
# Index(['名称', '价格', '月销量', '评价数', '店铺所在地', '适合肤质', '产地', '补水保湿', '美白提亮', '控油祛痘',
#        '清洁毛孔', '提拉紧致'],
#       dtype='object')

# %%
df['适合肤质'].unique()
# Out:
# array(['任何肤质', '干性肤质', '油性及混合性肤质', '中性及干性肤质', '混合型肤质', '敏感性肤质', '中性肤质',
#        '油性肤质'], dtype=object)

# %%
df
# Out:
#          名称     价格   月销量    评价数 店铺所在地  适合肤质  产地  补水保湿  美白提亮  控油祛痘  清洁毛孔  提拉紧致
# 0    ANGLEE  254.0    40   3133    湖南  任何肤质  中国     1     1     0     0     0
# 1    ANGLEE  350.0    62    876    浙江  任何肤质  中国     1     1     0     0     0
# 2    ANGLEE  284.9    12     16    浙江  任何肤质  中国     1     0     1     1     0
# 3        BF  289.0    32    175    英国  任何肤质  中国     1     0     0     0     0
# 4       BSR  379.9  1407  13870    安徽  任何肤质  中国     1     0     0     0     0
# ..      ...    ...   ...    ...   ...   ...  ..   ...   ...   ...   ...   ...
# 789     自然堂  122.0  1077   1715    上海  任何肤质  中国     1     1     0     0     0
# 790     自然堂  112.5   232   1887    上海  任何肤质  中国     1     0     0     1     0
# 791     自然堂   29.0   282    297    上海  任何肤质  中国     1     1     1     1     1
# 792     自然堂  173.0  1002   2389    浙江  任何肤质  中国     1     1     0     0     0
# 793     自然堂  119.0   100    106    浙江  任何肤质  中国     1     1     1     0     0
#
# [794 rows x 12 columns]

# %%
df_x=pd.concat([df.iloc[:,1],df.iloc[:,3],df.iloc[:,7:]],axis=1)

# %%
df_y=df.iloc[:,2]

# %%
model = LassoLars(alpha=1)  # LASSO回归的特点是在拟合广义线性模型的同时进行变量筛选和复杂度调整，剔除存在共线性的变量
model.fit(df_x,df_y)
#pd.DataFrame(model.coef_,columns=['x%d' %i for i in np.arange(13)+1])
model_coef=pd.DataFrame(pd.DataFrame(model.coef_).T)
model_coef.columns=df_x.columns
pd.set_option('display.max_columns', None)
model_coef
# Out:
#          价格       评价数  补水保湿       美白提亮  控油祛痘        清洁毛孔  提拉紧致
# 0 -0.560269  0.106354   0.0 -76.825271   0.0 -201.782742   0.0

# %%
df_x
# Out:
#         价格    评价数  补水保湿  美白提亮  控油祛痘  清洁毛孔  提拉紧致
# 0    254.0   3133     1     1     0     0     0
# 1    350.0    876     1     1     0     0     0
# 2    284.9     16     1     0     1     1     0
# 3    289.0    175     1     0     0     0     0
# 4    379.9  13870     1     0     0     0     0
# ..     ...    ...   ...   ...   ...   ...   ...
# 789  122.0   1715     1     1     0     0     0
# 790  112.5   1887     1     0     0     1     0
# 791   29.0    297     1     1     1     1     1
# 792  173.0   2389     1     1     0     0     0
# 793  119.0    106     1     1     1     0     0
#
# [794 rows x 7 columns]
