# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import *
import seaborn as sns

# %%
data = pd.read_csv('dailyprice.txt',header=0, delimiter='\t')

# %%
data.head()
# Out:
#    datetime trade_code   open   high    low  close     volume         amt  \
# 0  2003-1-2  000001.SZ  10.35  10.35   9.99  10.03  6484885.0  65629648.8
# 1  2003-1-2  000002.SZ   9.48   9.50   9.19   9.20   790027.0   7356678.1
# 2  2003-1-2  000004.SZ  14.50  14.58  14.20  14.37   220233.0   3162635.7
# 3  2003-1-2  000005.SZ   4.56   4.59   4.45   4.47  1240283.0   5591371.2
# 4  2003-1-2  000006.SZ   8.05   8.50   8.02   8.09   230641.0   1876922.5
#
#     chg  pct_chg  adjfactor    turn  free_turn  total_shares       mkt_cap  \
# 0 -0.46  -4.3851  24.613614  0.4601     0.5776  1.945822e+09  1.951660e+10
# 1 -0.45  -4.6632   6.012836  0.1981     0.1981  6.309747e+08  5.804967e+09
# 2 -0.62  -4.1361   3.119132  0.5287     0.5287  8.397668e+07  1.206745e+09
# 3 -0.09  -1.9737   5.616727  0.3317     0.3317  7.086613e+08  3.167716e+09
# 4 -0.08  -0.9792   4.249905  0.1462     0.1462  2.535916e+08  2.051556e+09
#
# ...

# %%
df=data

# %%
#选取代码为000676.SZ的数据
test_1=df[df['trade_code']=='000676.SZ']

# %%
test_1.head()
# Out:
#       datetime trade_code   open   high    low  close    volume        amt  \
# 233   2003-1-2  000676.SZ  17.89  17.90  17.77  17.83  184900.0  3297236.0
# 1365  2003-1-3  000676.SZ  17.75  17.87  17.70  17.79  133991.0  2382810.1
# 2497  2003-1-6  000676.SZ  17.79  17.86  17.69  17.82  184929.0  3291305.2
# 3630  2003-1-7  000676.SZ  17.82  17.88  17.71  17.83  160300.0  2854775.0
# 4764  2003-1-8  000676.SZ  17.83  17.88  17.70  17.86  150343.0  2679141.0
#
#        chg  pct_chg  adjfactor    turn  free_turn  total_shares       mkt_cap  \
# 233  -0.06  -0.3354   5.976532  0.1892     0.1892   314586699.0  5.609081e+09
# 1365 -0.04  -0.2243   5.976532  0.1371     0.1371   314586699.0  5.596497e+09
# 2497  0.03   0.1686   5.976532  0.1892     0.1892   314586699.0  5.605935e+09
# 3630  0.01   0.0561   5.976532  0.1640     0.1640   314586699.0  5.609081e+09
# 4764  0.03   0.1683   5.976532  0.1538     0.1538   314586699.0  5.618518e+09
#
# ...

# %%
chg=test_1.iloc[:,8]
plt.figure(figsize = (8,3))
plt.hist(chg,bins=100,color='red',alpha = 0.4)
plt.xlim(-0.7,0.7)
plt.title("chg distribution")
plt.xlabel("chg")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
import seaborn as sns 
plt.figure(figsize = (5,3))
sns.set_palette("hls") 
sns.distplot(chg,color="r",bins=80,kde=True,hist=True,rug=True)
plt.xlim(-0.6,0.6)
plt.ylim(0,7)
plt.title("chg distribution")
plt.xlabel("chg")
plt.ylabel("probability density")
# Out:
# Text(0, 0.5, 'probability density')

# %%
import numpy as np  
import seaborn as sns  
import matplotlib.pyplot as plt  
sns.set( palette="dark", color_codes=True)  
rs = np.random.RandomState(10)  
d = rs.normal(size=100)  
f, axes = plt.subplots(2, 2, figsize=(7, 4), sharex=True)  
sns.distplot(chg, kde=False, color="b", ax=axes[0, 0])  
sns.distplot(chg, hist=False, rug=True, color="r", ax=axes[0, 1])  
sns.distplot(chg,hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])  
sns.distplot(chg,color="m", ax=axes[1, 1])  
plt.xlim(-0.7,0.7)
plt.show()

# %%
test_1
# Out:
#           datetime trade_code   open   high    low  close    volume  \
# 233       2003-1-2  000676.SZ  17.89  17.90  17.77  17.83  184900.0
# 1365      2003-1-3  000676.SZ  17.75  17.87  17.70  17.79  133991.0
# 2497      2003-1-6  000676.SZ  17.79  17.86  17.69  17.82  184929.0
# 3630      2003-1-7  000676.SZ  17.82  17.88  17.71  17.83  160300.0
# 4764      2003-1-8  000676.SZ  17.83  17.88  17.70  17.86  150343.0
# 5898      2003-1-9  000676.SZ  17.86  17.96  17.76  17.93  361036.0
# 7032     2003-1-10  000676.SZ  17.90  17.97  17.32  17.33  206400.0
# 8166     2003-1-13  000676.SZ  17.40  17.44  16.98  16.99  130700.0
# 9300     2003-1-14  000676.SZ  17.05  17.11  16.75  17.06  406272.0
# 10435    2003-1-15  000676.SZ  17.05  17.10  16.50  16.54  296800.0
# 11570    2003-1-16  000676.SZ  16.30  16.60  15.99  16.56  946432.0
# 12705    2003-1-17  000676.SZ  16.33  17.00  16.22  16.87  627870.0
# 13840    2003-1-20  000676.SZ  16.85  17.07  16.73  17.07  690072.0
# ...

# %%
#选三支在时间上没有没有缺失数据的股票，000676.SZ/000551.SZ/000671.SZ 
df['trade_code'].value_counts().head(3)
# Out:
# 600783.SH    2988
# 600697.SH    2988
# 600674.SH    2988
# Name: trade_code, dtype: int64

# %%
list_2 = ['000676.SZ','000551.SZ','000671.SZ']
test_21 = df[df['trade_code']=='000676.SZ']
test_22=df[df['trade_code']=='000551.SZ']
test_23 = df[df['trade_code']=='000671.SZ']
test_2 = pd.concat([test_21,test_22,test_23],axis=0)

# %%
#筛选收盘价、时间、成交量字段
test_3 = test_2[['datetime','trade_code','close','volume']]

# %%
#为避免图形混乱，选取2008年8月的数据
from pandas import to_datetime
test_3['datetime']=pd.to_datetime(test_3['datetime'],format="%Y-%m-%d")
# Out:
# B:\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test_4 = test_3.set_index('datetime')

# %%
test_5 = test_4['2008-7':'2008-9']

# %%
test_5
# Out:
#            trade_code  close     volume
# datetime
# 2008-07-01  000676.SZ   3.75  1154578.0
# 2008-07-02  000676.SZ   3.89  1325244.0
# 2008-07-03  000676.SZ   4.00  2379164.0
# 2008-07-04  000676.SZ   4.00  1853640.0
# 2008-07-07  000676.SZ   4.19  3444571.0
# 2008-07-08  000676.SZ   4.23  3323065.0
# 2008-07-09  000676.SZ   4.57  6740643.0
# 2008-07-10  000676.SZ   4.66  8296614.0
# 2008-07-11  000676.SZ   4.62  5692518.0
# 2008-07-14  000676.SZ   4.62  5603123.0
# 2008-07-15  000676.SZ   4.43  3115697.0
# 2008-07-16  000676.SZ   4.31  3869210.0
# 2008-07-17  000676.SZ   4.38  2267481.0
# 2008-07-18  000676.SZ   4.37  3321865.0
# 2008-07-21  000676.SZ   4.48  2278984.0
# 2008-07-22  000676.SZ   4.46  2170393.0
# 2008-07-23  000676.SZ   4.33  2079050.0
# 2008-07-24  000676.SZ   4.46  2356377.0
# 2008-07-25  000676.SZ   4.40  1915250.0
# 2008-07-28  000676.SZ   4.45  1759572.0
# 2008-07-29  000676.SZ   4.37  1859129.0
# 2008-07-30  000676.SZ   4.45  2178779.0
# ...

# %%
#生成为了区分不同股票的颜色列
test_5["color"] = test_5["trade_code"].map({'000676.SZ':'lightcoral','000551.SZ':'lightseagreen','000671.SZ':'darkgrey'})
# Out:
# B:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test_5
# Out:
#            trade_code  close     volume color
# datetime
# 2008-07-01  000676.SZ   3.75  1154578.0     b
# 2008-07-02  000676.SZ   3.89  1325244.0     b
# 2008-07-03  000676.SZ   4.00  2379164.0     b
# 2008-07-04  000676.SZ   4.00  1853640.0     b
# 2008-07-07  000676.SZ   4.19  3444571.0     b
# 2008-07-08  000676.SZ   4.23  3323065.0     b
# 2008-07-09  000676.SZ   4.57  6740643.0     b
# 2008-07-10  000676.SZ   4.66  8296614.0     b
# 2008-07-11  000676.SZ   4.62  5692518.0     b
# 2008-07-14  000676.SZ   4.62  5603123.0     b
# 2008-07-15  000676.SZ   4.43  3115697.0     b
# 2008-07-16  000676.SZ   4.31  3869210.0     b
# 2008-07-17  000676.SZ   4.38  2267481.0     b
# 2008-07-18  000676.SZ   4.37  3321865.0     b
# 2008-07-21  000676.SZ   4.48  2278984.0     b
# 2008-07-22  000676.SZ   4.46  2170393.0     b
# 2008-07-23  000676.SZ   4.33  2079050.0     b
# 2008-07-24  000676.SZ   4.46  2356377.0     b
# 2008-07-25  000676.SZ   4.40  1915250.0     b
# ...

# %%
plt.figure(figsize=(7,5))
plt.scatter(test_5.index,test_5['close'],s=test_5['volume']/4000,alpha=0.5,c=test_5['color'])
plt.xlabel("date")
plt.ylabel("close")
plt.xlim('2008-7','2008-10')
plt.xticks(rotation=30, fontsize=8)
# Out:
# (array([733224., 733238., 733252., 733255., 733269., 733283., 733286.,
#         733300., 733314., 733316.]), <a list of 10 Text xticklabel objects>)

# %%
test_1.head()
# Out:
#       datetime trade_code   open   high    low  close    volume        amt  \
# 233   2003-1-2  000676.SZ  17.89  17.90  17.77  17.83  184900.0  3297236.0
# 1365  2003-1-3  000676.SZ  17.75  17.87  17.70  17.79  133991.0  2382810.1
# 2497  2003-1-6  000676.SZ  17.79  17.86  17.69  17.82  184929.0  3291305.2
# 3630  2003-1-7  000676.SZ  17.82  17.88  17.71  17.83  160300.0  2854775.0
# 4764  2003-1-8  000676.SZ  17.83  17.88  17.70  17.86  150343.0  2679141.0
#
#        chg  pct_chg  adjfactor    turn  free_turn  total_shares       mkt_cap  \
# 233  -0.06  -0.3354   5.976532  0.1892     0.1892   314586699.0  5.609081e+09
# 1365 -0.04  -0.2243   5.976532  0.1371     0.1371   314586699.0  5.596497e+09
# 2497  0.03   0.1686   5.976532  0.1892     0.1892   314586699.0  5.605935e+09
# 3630  0.01   0.0561   5.976532  0.1640     0.1640   314586699.0  5.609081e+09
# 4764  0.03   0.1683   5.976532  0.1538     0.1538   314586699.0  5.618518e+09
#
# ...

# %%
test_6 = test_1[['open','high','turn','volume','free_float_shares']]

# %%
pd.scatter_matrix(test_6,figsize =(10,7))
# Out:
# B:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F60244E518>,
# ...
#       dtype=object)

# %%
import seaborn as sns
correlations = test_1.corr() 
correction=abs(correlations)# 取绝对值，只看相关程度 ，不关心正相关还是负相关
# plot correlation matrix 
ax = sns.heatmap(correction,cmap=plt.cm.Greys, linewidths=0.05,vmax=1, vmin=0 ,annot=True,annot_kws={'size':6,'weight':'bold'})

# %%
test_7=df[df['trade_code']=='000671.SZ']
test_8 = df[df['trade_code']=='000672.SZ']

# %%
p1=sns.kdeplot(test_1['high'], shade=True, color="r",alpha=0.4,label='000676.SZ')
p1=sns.kdeplot(test_7['high'], shade=True, color="b",alpha=0.4,label='000671.SZ')
p1=sns.kdeplot(test_8['high'], shade=True, color="g",alpha=0.4,label='000672.SZ')

# %%
sns.jointplot(x=test_8["open"], y=test_7["open"], kind='kde', color="grey",space=0,size=3)
# Out:
# B:\anaconda\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#为啥不出来啊？？？
x=test_7['open']
y= test_8['open']
#sns.kdeplot(x, y,cmap="Reds", shade=True, shade_lowest=False)
#a=sns.kdeplot(test_8.open, test_8.high,cmap="Blues", shade=True, shade_lowest=False)

# %%
# Out:
# 16.50    115
# 6.04      45
# 5.35      37
# 20.06     20
# 9.00      16
# 8.90      13
# 8.50      13
# 8.00      13
# 8.75      12
# 8.70      12
# 9.30      12
# 6.40      11
# 7.15      11
# 6.50      11
# 7.90      10
# 8.10      10
# 7.00      10
# 8.45      10
# 8.88       9
# 11.50      9
# 12.70      9
# 9.20       9
# 8.96       9
# 9.10       9
# 8.80       8
# 6.80       8
# 9.40       8
# 9.18       8
# 11.20      8
# 6.28       8
#         ...
# 22.35      1
# 28.17      1
# 17.57      1
# 7.44       1
# 22.19      1
# 4.20       1
# 14.61      1
# 27.58      1
# 36.29      1
# 26.68      1
# 15.41      1
# 12.18      1
# 18.20      1
# 11.72      1
# 13.24      1
# 36.06      1
# 10.03      1
# 12.42      1
# 15.55      1
# 10.48      1
# 9.79       1
# 27.34      1
# 3.57       1
# 5.94       1
# 4.95       1
# 30.16      1
# 21.08      1
# 12.87      1
# 8.36       1
# 7.91       1
# Name: open, Length: 1129, dtype: int64

# %%
test_6.head()
# Out:
#        open   high    turn    volume  free_float_shares
# 233   17.89  17.90  0.1892  184900.0         97750000.0
# 1365  17.75  17.87  0.1371  133991.0         97750000.0
# 2497  17.79  17.86  0.1892  184929.0         97750000.0
# 3630  17.82  17.88  0.1640  160300.0         97750000.0
# 4764  17.83  17.88  0.1538  150343.0         97750000.0

# %%
testhot = test_6[['open','high','turn']]

# %%
热力图画横轴月份 纵轴年份 深浅表示成交量这种的
